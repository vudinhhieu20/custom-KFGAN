# %%
# !python preprocess.py -d book
# Out:
# [2024-07-24 20:54:47,509] INFO: reading item index to entity id file: ../data/book/item_index2entity_id.txt
# [2024-07-24 20:54:47,514] INFO: reading rating file: ../data/book/BX-Book-Ratings.csv
# [2024-07-24 20:54:48,102] INFO: converting rating file to: ../data/book/ratings_final.txt
# [2024-07-24 20:54:56,243] INFO: number of users: 17860
# [2024-07-24 20:54:56,243] INFO: number of items: 14967
# [2024-07-24 20:54:56,243] INFO: number of interactions: 139746
# [2024-07-24 20:54:56,244] INFO: reading kg file: ../data/book/kg.txt
# [2024-07-24 20:54:56,244] INFO: converting kg file to: ../data/book/kg_final.txt
# [2024-07-24 20:54:56,333] INFO: number of entities (containing items): 77903
# [2024-07-24 20:54:56,333] INFO: number of relations: 25
# [2024-07-24 20:54:56,333] INFO: number of triples: 151500
# [2024-07-24 20:54:56,333] INFO: data book preprocess: done.

# %%
# !python main.py --batch_size 1024
# Out:
# [2024-07-21 10:58:16,056] INFO: ================== preparing data ===================
# [2024-07-21 10:58:16,056] INFO: load rating file: ../data/music/ratings_final.npy
# [2024-07-21 10:58:16,057] INFO: splitting dataset to 6:2:2 ...
# [2024-07-21 10:58:16,063] INFO: contructing users' initial entity set ...
# [2024-07-21 10:58:16,087] INFO: construct user's potential initial entity set ...
# [2024-07-21 10:58:16,457] INFO: contructing items' potential entity set ...
# [2024-07-21 10:58:16,477] INFO: contructing items' origin entity set ...
# [2024-07-21 10:58:16,486] INFO: loading kg file: ../data/music/kg_final.npy
# [2024-07-21 10:58:16,487] INFO: constructing knowledge graph ...
# [2024-07-21 10:58:16,493] INFO: contructing users' initial kg triple sets ...
# [2024-07-21 10:58:17,007] INFO: contructing items' potential triple sets ...
# [2024-07-21 10:58:18,125] INFO: constructing users' potential kg triple sets ...
# ...

# %%
# !python main.py --batch_size 1024 --n_epoch 10
# Out:
# [2024-07-22 22:35:52,590] INFO: ================== preparing data ===================
# [2024-07-22 22:35:52,590] INFO: load rating file: ../data/music/ratings_final.npy
# [2024-07-22 22:35:52,590] INFO: splitting dataset to 6:2:2 ...
# [2024-07-22 22:35:52,596] INFO: contructing users' initial entity set ...
# [2024-07-22 22:35:52,620] INFO: construct user's potential initial entity set ...
# [2024-07-22 22:35:52,987] INFO: contructing items' potential entity set ...
# [2024-07-22 22:35:53,008] INFO: contructing items' origin entity set ...
# [2024-07-22 22:35:53,015] INFO: loading kg file: ../data/music/kg_final.npy
# [2024-07-22 22:35:53,017] INFO: constructing knowledge graph ...
# [2024-07-22 22:35:53,052] INFO: contructing users' initial kg triple sets ...
# [2024-07-22 22:36:28,495] INFO: contructing items' potential triple sets ...
# [2024-07-22 22:37:43,256] INFO: constructing users' potential kg triple sets ...
# ...

# %%
# !python main.py --batch_size 1024 --n_epoch 50
# Out:
# [2024-07-23 21:14:54,923] INFO: ================== preparing data ===================
# [2024-07-23 21:14:54,924] INFO: load rating file: ../data/music/ratings_final.npy
# [2024-07-23 21:14:54,924] INFO: splitting dataset to 6:2:2 ...
# [2024-07-23 21:14:54,930] INFO: contructing users' initial entity set ...
# [2024-07-23 21:14:54,954] INFO: construct user's potential initial entity set ...
# [2024-07-23 21:14:55,323] INFO: contructing items' potential entity set ...
# [2024-07-23 21:14:55,344] INFO: contructing items' origin entity set ...
# [2024-07-23 21:14:55,351] INFO: loading kg file: ../data/music/kg_final.npy
# [2024-07-23 21:14:55,353] INFO: constructing knowledge graph ...
# [2024-07-23 21:14:55,389] INFO: contructing users' initial kg triple sets ...
# [2024-07-23 21:15:39,714] INFO: contructing items' potential triple sets ...
# [2024-07-23 21:17:13,792] INFO: constructing users' potential kg triple sets ...
# ...

# %%
# !python main.py --batch_size 1024 --n_epoch 10 --agg pool
# Out:
# [2024-07-23 21:52:50,119] INFO: ================== preparing data ===================
# [2024-07-23 21:52:50,119] INFO: load rating file: ../data/music/ratings_final.npy
# [2024-07-23 21:52:50,120] INFO: splitting dataset to 6:2:2 ...
# [2024-07-23 21:52:50,126] INFO: contructing users' initial entity set ...
# [2024-07-23 21:52:50,149] INFO: construct user's potential initial entity set ...
# [2024-07-23 21:52:50,521] INFO: contructing items' potential entity set ...
# [2024-07-23 21:52:50,542] INFO: contructing items' origin entity set ...
# [2024-07-23 21:52:50,550] INFO: loading kg file: ../data/music/kg_final.npy
# [2024-07-23 21:52:50,551] INFO: constructing knowledge graph ...
# [2024-07-23 21:52:50,589] INFO: contructing users' initial kg triple sets ...
# [2024-07-23 21:53:33,482] INFO: contructing items' potential triple sets ...
# [2024-07-23 21:55:04,183] INFO: constructing users' potential kg triple sets ...
# ...

# %%
# !python main.py --batch_size 1024 --n_epoch 20 --agg sum
# Out:
# [2024-07-23 22:17:06,184] INFO: ================== preparing data ===================
# [2024-07-23 22:17:06,184] INFO: load rating file: ../data/music/ratings_final.npy
# [2024-07-23 22:17:06,185] INFO: splitting dataset to 6:2:2 ...
# [2024-07-23 22:17:06,191] INFO: contructing users' initial entity set ...
# [2024-07-23 22:17:06,214] INFO: construct user's potential initial entity set ...
# [2024-07-23 22:17:06,587] INFO: contructing items' potential entity set ...
# [2024-07-23 22:17:06,609] INFO: contructing items' origin entity set ...
# [2024-07-23 22:17:06,616] INFO: loading kg file: ../data/music/kg_final.npy
# [2024-07-23 22:17:06,618] INFO: constructing knowledge graph ...
# [2024-07-23 22:17:06,656] INFO: contructing users' initial kg triple sets ...
# [2024-07-23 22:17:49,663] INFO: contructing items' potential triple sets ...
# [2024-07-23 22:19:21,539] INFO: constructing users' potential kg triple sets ...
# ...

# %%
# !python main.py --batch_size 1024 --n_epoch 10 -d book
# Out:
# [2024-07-24 20:57:28,335] INFO: ================== preparing data ===================
# [2024-07-24 20:57:28,335] INFO: load rating file: ../data/book/ratings_final.npy
# [2024-07-24 20:57:28,337] INFO: splitting dataset to 6:2:2 ...
# [2024-07-24 20:57:28,359] INFO: contructing users' initial entity set ...
# [2024-07-24 20:57:28,444] INFO: construct user's potential initial entity set ...
# [2024-07-24 20:57:33,086] INFO: contructing items' potential entity set ...
# [2024-07-24 20:57:33,266] INFO: contructing items' origin entity set ...
# [2024-07-24 20:57:33,292] INFO: loading kg file: ../data/book/kg_final.npy
# [2024-07-24 20:57:33,310] INFO: constructing knowledge graph ...
# [2024-07-24 20:57:33,463] INFO: contructing users' initial kg triple sets ...
# [2024-07-24 21:09:13,185] INFO: contructing items' potential triple sets ...
# [2024-07-24 21:21:23,314] INFO: constructing users' potential kg triple sets ...
# ...
